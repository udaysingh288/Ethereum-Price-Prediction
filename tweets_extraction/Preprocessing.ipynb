# %%
import pandas as pd

# %% [markdown]
# # Lets Load the Json First

# %%
Oct = pd.read_json('tweetsOct.json')
Oct.head()
# Out:
#            fullname                                               html  \
# 0   zentrade.online  <p class="TweetTextSize js-tweet-text tweet-te...
# 1   Goodstockinvest  <p class="TweetTextSize js-tweet-text tweet-te...
# 2  Investors Europe  <p class="TweetTextSize js-tweet-text tweet-te...
# 3      CRyptOTAtioN  <p class="TweetTextSize js-tweet-text tweet-te...
# 4             AlexT  <p class="TweetTextSize js-tweet-text tweet-te...
#
#                    id  likes  replies  retweets  \
# 0  920076749081403392      1        0         0
# 1  920076678130307072      0        0         0
# 2  920076645700198400      0        0         0
# 3  920076534836269056      0        0         0
# 4  920076505425817600      2        0         2
#
#                                                 text           timestamp  \
# 0  Fund manager Novogratz agrees to advise ethere... 2017-10-16 23:59:25
# 1  [Hb6EP.[F.R.E.E] [D.O.W.N.L.O.A.D]] Ethereum: ... 2017-10-16 23:59:08
# ...

# %% [markdown]
# # Let's Delete the columns which are not necessary for our analysis plan

# %%
del Oct['html']
del Oct['id']
del Oct['likes']
del Oct['replies']
del Oct['retweets']
del Oct['url']
del Oct['user']
# Out:
#    Unnamed: 0                                               text  \
# 0           0  Why the XRP Ledger will decentralize further t...
# 1           1  Bitcoin: €11,077.51\r\nEthereum: €1,041.3\r\nL...
# 2           2  Ethereum $ETH price: $1290.60 \r\n\r\nBinance ...
# 3           3  Upcoming #ETC snapshot ≫ All Ethereum Classic ...
# 4           4  Sign up on Binance while you can  , registrati...
#
#              timestamp
# 0  2018-01-15 23:59:28
# 1  2018-01-15 23:59:13
# 2  2018-01-15 23:59:06
# 3  2018-01-15 23:59:06
# 4  2018-01-15 23:59:04

# %% [markdown]
# # Lets Convert the Json to csv.

# %%
Jan.to_csv('Jantweets.csv')
print("Converted to CSV!!")

# %% [markdown]
# # Repeat the same step to other Json files.

# %%
Nov = pd.read_json('tweetsNov.json')
Nov.head()
# Out:
#          fullname                                               html  \
# 0       Ricardo N  <p class="TweetTextSize js-tweet-text tweet-te...
# 1       CoinPilot  <p class="TweetTextSize js-tweet-text tweet-te...
# 2   Travelog View  <p class="TweetTextSize js-tweet-text tweet-te...
# 3  Coin Spectator  <p class="TweetTextSize js-tweet-text tweet-te...
# 4        kemet km  <p class="TweetTextSize js-tweet-text tweet-te...
#
#                    id  likes  replies  retweets  \
# 0  930223743657566208      0        0         0
# 1  930223621515046912      1        0         0
# 2  930223554238603264      0        0         0
# 3  930223407978905600      0        0         0
# 4  930223407748210688      0        0         0
#
#                                                 text           timestamp  \
# 0  Do not feel more lost on a trip, use the platf... 2017-11-13 23:59:57
# 1  All Eyes On Dash As Currency Surges 60% Despit... 2017-11-13 23:59:28
# ...

# %%
del Nov['html']
del Nov['id']
del Nov['likes']
del Nov['replies']
del Nov['retweets']
del Nov['url']
del Nov['user']

# %%
Nov.to_csv('Novtweets.csv')

# %%
Dec = pd.read_json('tweetsDec.json')
Dec.head()
# Out:
#                fullname                                               html  \
# 0    Cryptocurrency_Bot  <p class="TweetTextSize js-tweet-text tweet-te...
# 1  Finding Crypto(jeff)  <p class="TweetTextSize js-tweet-text tweet-te...
# 2   Global Stock Broker  <p class="TweetTextSize js-tweet-text tweet-te...
# 3               Daman M  <p class="TweetTextSize js-tweet-text tweet-te...
# 4              XBTmoney  <p class="TweetTextSize js-tweet-text tweet-te...
#
#                    id  likes  replies  retweets  \
# 0  936746594854100992      0        0         0
# 1  936746520430362624      0        0         0
# 2  936746484577505280      0        0         0
# 3  936746450838437888      1        0         1
# 4  936746265886339072      0        0         0
#
#                                                 text           timestamp  \
# 0  Korea price\nTime: 12/02 08:59:26\nBTC: 12,497... 2017-12-01 23:59:26
# 1  Earn Free Ethereum every 2-3 Minutes. Next Day... 2017-12-01 23:59:09
# ...

# %%
del Dec['html']
del Dec['fullname']
del Dec['id']
del Dec['likes']
del Dec['replies']
del Dec['retweets']
del Dec['url']
del Dec['user']

# %%
Dec.to_csv('Dectweets.csv')

# %%
Jan = pd.read_json('tweetsJan.json')
del Jan['html']
del Jan['fullname']
del Jan['id']
del Jan['likes']
del Jan['replies']
del Jan['retweets']
del Jan['url']
del Jan['user']

# %%
Jan.to_csv('Jantweets.csv')

# %%
Feb = pd.read_json('tweetsFeb.json')
del Feb['html']
del Feb['fullname']
del Feb['id']
del Feb['likes']
del Feb['replies']
del Feb['retweets']
del Feb['url']
del Feb['user']

# %%
Feb.to_csv('Febtweets.csv')

# %%
Mar = pd.read_json('tweetsMarch.json')
del Mar['html']
del Mar['fullname']
del Mar['id']
del Mar['likes']
del Mar['replies']
del Mar['retweets']
del Mar['url']
del Mar['user']

# %%
Mar.to_csv('Marchtweets.csv')
